# %%
from PIL import Image, ImageOps
import fitz
import numpy
from pprint import pprint

pdf = fitz.open('../input/method6.pdf')

print(pdf[0].read_contents())

pdf.close()
# Out:
# b'/Artifact BMC q\r\n0 0.000061035 595.32 841.92 re\r\nW* n\r\n/GS5 gs\r\n1 g\r\n-0 -0.13 595.45 842.05 re\r\nf*\r\nQ\r\n EMC  /Span <</MCID 0/Lang (id)>> BDC q\r\n0.000008871 0 595.32 841.92 re\r\nW* n\r\n17.28 0 0 14.76 113.3 742.06 cm\r\n/Image6 Do Q\r\n EMC  /Span <</MCID 1/Lang (id)>> BDC q\r\n0.000008871 0 595.32 841.92 re\r\nW* n\r\n11.04 0 0 14.76 121.94 742.06 cm\r\n/Image8 Do Q\r\n EMC  /Span <</MCID 2/Lang (id)>> BDC q\r\n0.000008871 0 595.32 841.92 re\r\nW* n\r\n6.72 0 0 14.76 127.46 742.06 cm\r\n/Image10 Do Q\r\n EMC  /Span <</MCID 3/Lang (id)>> BDC q\r\n0.000008871 0 595.32 841.92 re\r\nW* n\r\n11.04 0 0 14.76 130.82 742.06 cm\r\n/Image8 Do Q\r\n EMC  /Span <</MCID 4/Lang (id)>> BDC q\r\n0.000008871 0 595.32 841.92 re\r\nW* n\r\n17.76 0 0 14.76 136.34 742.06 cm\r\n/Image12 Do Q\r\n EMC  /Span <</MCID 5/Lang (id)>> BDC q\r\n0.000008871 0 595.32 841.92 re\r\nW* n\r\n17.76 0 0 14.76 158.66 742.06 cm\r\n/Image14 Do Q\r\n EMC  /Span <</MCID 6/Lang (id)>> BDC q\r\n0.000008871
# ...
